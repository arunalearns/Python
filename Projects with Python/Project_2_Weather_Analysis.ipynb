# %%
import pandas as pd
df= pd.read_csv("weather_2012.csv")

# %%
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %%
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df["Date/Time"].head()
# Out:
# 0    2012-01-01 00:00:00
# 1    2012-01-01 01:00:00
# 2    2012-01-01 02:00:00
# 3    2012-01-01 03:00:00
# 4    2012-01-01 04:00:00
# Name: Date/Time, dtype: object

# %%
type(df["Date/Time"].head())
# Out:
# pandas.core.series.Series

# %% [markdown]
# Let's convert the Date/Time column datatype from object to timestamp so that we can access the month directly using the attribute dt.month

# %%
df["Date/Time"] = pd.to_datetime(df["Date/Time"])

# %%
df["Date/Time"].head()
# Out:
# 0   2012-01-01 00:00:00
# 1   2012-01-01 01:00:00
# 2   2012-01-01 02:00:00
# 3   2012-01-01 03:00:00
# 4   2012-01-01 04:00:00
# Name: Date/Time, dtype: datetime64[ns]

# %%
df["Date/Time"].tail()
# Out:
# 8779   2012-12-31 19:00:00
# 8780   2012-12-31 20:00:00
# 8781   2012-12-31 21:00:00
# 8782   2012-12-31 22:00:00
# 8783   2012-12-31 23:00:00
# Name: Date/Time, dtype: datetime64[ns]

# %% [markdown]
# How to Analyze DataFrames?

# %%
# To understand the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date/Time           8784 non-null   datetime64[ns]
#  1   Temp (C)            8784 non-null   float64
#  2   Dew Point Temp (C)  8784 non-null   float64
#  3   Rel Hum (%)         8784 non-null   int64
#  4   Wind Spd (km/h)     8784 non-null   int64
#  5   Visibility (km)     8784 non-null   float64
#  6   Stn Press (kPa)     8784 non-null   float64
#  7   Weather             8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
df.head(10)
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
# 5 2012-01-01 05:00:00      -1.4                -3.3           87
# 6 2012-01-01 06:00:00      -1.5                -3.1           89
# 7 2012-01-01 07:00:00      -1.4                -3.6           85
# 8 2012-01-01 08:00:00      -1.4                -3.6           85
# 9 2012-01-01 09:00:00      -1.3                -3.1           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# ...

# %%
df["Weather"].unique() # This function will give you the unique values of a column
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df["Weather"].nunique() # This function will give you the number of unique values
# Out:
# 50

# %%
df["Wind Spd (km/h)"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
df["Wind Spd (km/h)"].nunique()
# Out:
# 34

# %%
df["Weather"].value_counts()[2]
# Out:
# C:\Users\Aruna Tangirala\AppData\Local\Temp\ipykernel_20296\945429564.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["Weather"].value_counts()[2]
# np.int64(1728)

# %% [markdown]
# # DATA Manipulation
# How to get the Weather column from the "df" dataframe

# %%
col = df["Weather"] # To fetch one column 
col.head()
# Out:
# 0                     Fog
# 1                     Fog
# 2    Freezing Drizzle,Fog
# 3    Freezing Drizzle,Fog
# 4                     Fog
# Name: Weather, dtype: object

# %%
    col1 = df[["Weather","Wind Spd (km/h)"]] # To fetch more than one column  use double [[]]
col1.head()
# Out:
#                 Weather  Wind Spd (km/h)
# 0                   Fog                4
# 1                   Fog                4
# 2  Freezing Drizzle,Fog                7
# 3  Freezing Drizzle,Fog                6
# 4                   Fog                7

# %%
df[["Weather","Wind Spd (km/h)"]][0:10:2] # slicing
# Out:
#                 Weather  Wind Spd (km/h)
# 0                   Fog                4
# 2  Freezing Drizzle,Fog                7
# 4                   Fog                7
# 6                   Fog                7
# 8                   Fog                9

# %%
df[0:10:2][["Weather","Wind Spd (km/h)"]] # slicing
# Out:
#                 Weather  Wind Spd (km/h)
# 0                   Fog                4
# 2  Freezing Drizzle,Fog                7
# 4                   Fog                7
# 6                   Fog                7
# 8                   Fog                9

# %% [markdown]
# Pandas provides a powerful way to work with both rows and columns together, optionally using their label indices or numeric indices.
#
# .loc :
# Purely label-location based indexer for selection by label (but may also be used with a boolean array).
# Important: If you use slicing in loc, it will return the end index as well
#
#
# .iloc:
# Purely integer-location based indexing for selection by position (but may also be used with a boolean array).
#
# Allowed inputs are:
#
# A single label, e.g. 5 or 'a'
# A list or array of labels, e.g. ['a', 'b', 'c']
# A slice object with labels, e.g. 'a':'f'

# %%
df.loc[0:5,["Weather","Wind Spd (km/h)"]] # Number of rows are 5 as it fetching based on lable actual lable
# Out:
#                 Weather  Wind Spd (km/h)
# 0                   Fog                4
# 1                   Fog                4
# 2  Freezing Drizzle,Fog                7
# 3  Freezing Drizzle,Fog                6
# 4                   Fog                7
# 5                   Fog                9

# %%
df[["Weather","Wind Spd (km/h)"]].iloc[0:5] # Number of rows are 5 as it fetching based on index starting from 0
# Out:
#                 Weather  Wind Spd (km/h)
# 0                   Fog                4
# 1                   Fog                4
# 2  Freezing Drizzle,Fog                7
# 3  Freezing Drizzle,Fog                6
# 4                   Fog                7

# %% [markdown]
# # FILTER

# %%
# Find all instances when snow was recorded

Snowfil = df['Weather'].str.lower().str.contains('snow')

# %%
Snowfil
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# 8783     True
# Name: Weather, Length: 8784, dtype: bool

# %%
df[Snowfil]
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 41    2012-01-02 17:00:00      -2.1                -9.5           57
# 44    2012-01-02 20:00:00      -5.6               -13.4           54
# 45    2012-01-02 21:00:00      -5.8               -12.8           58
# 47    2012-01-02 23:00:00      -7.4               -14.1           59
# 48    2012-01-03 00:00:00      -9.0               -16.0           57
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# ...

# %%
# Find all instances when wind speed was above 24 and visibility was 25

wind = (df['Wind Spd (km/h)'] > 24) & (df['Visibility (km)']== 25)
df[wind]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Length: 8784, dtype: bool

# %%
wind_df = df[(df['Wind Spd (km/h)'] > 24) & (df['Visibility (km)']== 25)]
wind_df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 23 2012-01-01 23:00:00       5.3                 2.0           79
# 24 2012-01-02 00:00:00       5.2                 1.5           77
# 25 2012-01-02 01:00:00       4.6                 0.0           72
# 26 2012-01-02 02:00:00       3.9                -0.9           71
# 27 2012-01-02 03:00:00       3.7                -1.5           69
#
#     Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 23               30             25.0            99.31         Cloudy
# 24               35             25.0            99.26   Rain Showers
# 25               39             25.0            99.26         Cloudy
# 26               32             25.0            99.26  Mostly Cloudy
# 27               33             25.0            99.30  Mostly Cloudy

# %%
df['Wind Spd (km/h)'].head()
# Out:
# 0    4
# 1    4
# 2    7
# 3    6
# 4    7
# Name: Wind Spd (km/h), dtype: int64

# %%
df['Wind Spd (km/h)'].head() + 10
# Out:
# 0    14
# 1    14
# 2    17
# 3    16
# 4    17
# Name: Wind Spd (km/h), dtype: int64

# %%
add_10 = df['Wind Spd (km/h)'].head() + 10

# %%
add_10.head()
# Out:
# 0    14
# 1    14
# 2    17
# 3    16
# 4    17
# Name: Wind Spd (km/h), dtype: int64

# %%
df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df['new_column']=df['Temp (C)'] + df['Dew Point Temp (C)']

# %%
df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    new_column
# 0        -5.7
# 1        -5.5
# 2        -5.2
# 3        -4.7
# 4        -4.8

# %%
def sum2(value):
    return value + value

def sub2(value)
     return value - 4

visi_df = df['Visibility (km)'].apply(sum2)

# %%
visi_df.head()
# Out:
# 0    16.0
# 1    16.0
# 2     8.0
# 3     8.0
# 4     9.6
# Name: Visibility (km), dtype: float64

# %%
 df['Visibility (km)'].describe()
# Out:
# count    8784.000000
# mean       27.664447
# std        12.622688
# min         0.200000
# 25%        24.100000
# 50%        25.000000
# 75%        25.000000
# max        48.300000
# Name: Visibility (km), dtype: float64

# %%
# Adding / updating column 
df['Visibility (km)'] = df['Visibility (km)'].apply(sum2)

# %%
df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4             16.0           101.24                   Fog
# 1                4             16.0           101.24                   Fog
# 2                7              8.0           101.26  Freezing Drizzle,Fog
# 3                6              8.0           101.27  Freezing Drizzle,Fog
# 4                7              9.6           101.23                   Fog
#
#    new_column
# 0        -5.7
# 1        -5.5
# 2        -5.2
# 3        -4.7
# 4        -4.8

# %%
def sub2(value):
     return value - 4
new_variable = df['Visibility (km)'].apply(sub2)

# %%
new_variable
# Out:
# 0       12.0
# 1       12.0
# 2        4.0
# 3        4.0
# 4        5.6
#         ...
# 8779    15.4
# 8780    15.4
# 8781     5.6
# 8782    15.4
# 8783    18.6
# Name: Visibility (km), Length: 8784, dtype: float64

# %%
df['Visibility (km)'] = new_variable 
df['Visibility (km)'].head()
# Out:
# 0    12.0
# 1    12.0
# 2     4.0
# 3     4.0
# 4     5.6
# Name: Visibility (km), dtype: float64

# %%
# Renaming 
# Notice the "inplace=True" parameter. This means the renaming has been assigned in the old DataFrame itself

df.rename(columns={'Visibility (km)': 'Visibility (meters)','Temp (C)':'Temp (Cel)'}, inplace=True)
df.head()
# Out:
#             Date/Time  Temp (Cel)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00        -1.8                -3.9           86
# 1 2012-01-01 01:00:00        -1.8                -3.7           87
# 2 2012-01-01 02:00:00        -1.8                -3.4           89
# 3 2012-01-01 03:00:00        -1.5                -3.2           88
# 4 2012-01-01 04:00:00        -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (meters)  Stn Press (kPa)  \
# 0                4                 12.0           101.24
# 1                4                 12.0           101.24
# 2                7                  4.0           101.26
# 3                6                  4.0           101.27
# 4                7                  5.6           101.23
#
#                 Weather  new_column
# 0                   Fog        -5.7
# 1                   Fog        -5.5
# 2  Freezing Drizzle,Fog        -5.2
# 3  Freezing Drizzle,Fog        -4.7
# ...

# %%
df = df.drop(labels=['Temp (Cel)'],axis=1)

# %%
df.head()
# Out:
#             Date/Time  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0 2012-01-01 00:00:00                -3.9           86                4
# 1 2012-01-01 01:00:00                -3.7           87                4
# 2 2012-01-01 02:00:00                -3.4           89                7
# 3 2012-01-01 03:00:00                -3.2           88                6
# 4 2012-01-01 04:00:00                -3.3           88                7
#
#    Visibility (meters)  Stn Press (kPa)               Weather  new_column
# 0                 12.0           101.24                   Fog        -5.7
# 1                 12.0           101.24                   Fog        -5.5
# 2                  4.0           101.26  Freezing Drizzle,Fog        -5.2
# 3                  4.0           101.27  Freezing Drizzle,Fog        -4.7
# 4                  5.6           101.23                   Fog        -4.8

# %% [markdown]
# # Which were the top 10 hottest values and their counts?

# %%
fil = df['Dew Point Temp (C)'].value_counts().sort_values(ascending=False)

# %% [markdown]
# df.sort_values(by='Dew Point Temp (C)',ascending=True).head()

# %%
# PIVOT

# %%
data = {
    'A': ['foo','foo','foo','bar','bar','bar'],
    'B': ['one','one','two','two','one','one'],
    'C': ['x','y','x','y','x','y'],
    'D': [1, 3, 2, 5, 4, 1]
}

df = pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
import numpy as np
pivot_df = df.pivot_table(
    values='D',
    index='A',
    columns=['C'],
    aggfunc=np.sum
)
pivot_df
# Out:
# C:\Users\Aruna Tangirala\AppData\Local\Temp\ipykernel_20296\1672727157.py:2: FutureWarning: The provided callable <function sum at 0x0000015EEB9C44A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot_df = df.pivot_table(
# C    x  y
# A
# bar  4  6
# foo  3  3

# %%
pivot_df.reset_index()
# Out:
# C    A  x  y
# 0  bar  4  6
# 1  foo  3  3

# %%
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
df[['Date/Time',	'Temp (C)']].head()
# Out:
#              Date/Time  Temp (C)
# 0  2012-01-01 00:00:00      -1.8
# 1  2012-01-01 01:00:00      -1.8
# 2  2012-01-01 02:00:00      -1.8
# 3  2012-01-01 03:00:00      -1.5
# 4  2012-01-01 04:00:00      -1.5

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# %%
df[['Date/Time',	'Temp (C)']].head()
# Out:
#             Date/Time  Temp (C)
# 0 2012-01-01 00:00:00      -1.8
# 1 2012-01-01 01:00:00      -1.8
# 2 2012-01-01 02:00:00      -1.8
# 3 2012-01-01 03:00:00      -1.5
# 4 2012-01-01 04:00:00      -1.5

# %%
pivot_df = df.pivot_table(
    values='Temp (C)',
    index=df['Date/Time'].dt.month,
    aggfunc=np.mean
)
pivot_df
# Out:
# C:\Users\Aruna Tangirala\AppData\Local\Temp\ipykernel_20296\4176788074.py:1: FutureWarning: The provided callable <function mean at 0x0000015EEB9C58A0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_df = df.pivot_table(
#             Temp (C)
# Date/Time
# 1          -7.371505
# 2          -4.225000
# 3           3.121237
# 4           7.009306
# 5          16.237769
# 6          20.134028
# 7          22.790054
# 8          22.279301
# 9          16.484444
# 10         10.954973
# 11          0.931389
# 12         -3.306317

# %%
df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
pivot2_df= df.pivot_table(values='Wind Spd (km/h)',
                          index=df['Date/Time'].dt.month,
                         
                         aggfunc=np.sum
)
pivot2_df
# Out:
# C:\Users\Aruna Tangirala\AppData\Local\Temp\ipykernel_20296\1604912694.py:1: FutureWarning: The provided callable <function sum at 0x0000015EEB9C44A0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot2_df= df.pivot_table(values='Wind Spd (km/h)',
#            Wind Spd (km/h)
# Date/Time
# 1                    13473
# 2                    10327
# 3                    10799
# 4                    12506
# 5                     9558
# 6                    10571
# 7                     8844
# 8                    10365
# 9                    10158
# 10                   11514
# 11                   10061
# 12                   13105

# %%
df.groupby(df["Date/Time"].dt.month).mean(numeric_only=True).reset_index()
# Out:
#     Date/Time   Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  \
# 0           1  -7.371505          -12.294758    68.383065        18.108871
# 1           2  -4.225000           -9.221695    68.956897        14.837644
# 2           3   3.121237           -3.488575    64.862903        14.514785
# 3           4   7.009306           -1.934583    56.150000        17.369444
# 4           5  16.237769            8.080780    61.760753        12.846774
# 5           6  20.134028           11.738056    60.643056        14.681944
# 6           7  22.790054           14.595430    62.017473        11.887097
# 7           8  22.279301           15.644758    67.943548        13.931452
# 8           9  16.484444           10.757917    71.165278        14.108333
# 9          10  10.954973            6.533468    75.731183        15.475806
# 10         11   0.931389           -4.179306    69.984722        13.973611
# ...

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
}, index=[0, 1, 2, 3])

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7']
}, index=[4, 5, 6, 7])

df3 = pd.DataFrame({
    'A': ['A8', 'A9', 'A10', 'A11'],
    'B': ['B8', 'B9', 'B10', 'B11'],
    'C': ['C8', 'C9', 'C10', 'C11'],
    'E': ['D8', 'D9', 'D10', 'D11']
}, index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    E
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1) # it will merge column vise
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    E
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3]) # it will merge row vise
# Out:
#       A    B    C    D    E
# 0    A0   B0   C0   D0  NaN
# 1    A1   B1   C1   D1  NaN
# 2    A2   B2   C2   D2  NaN
# 3    A3   B3   C3   D3  NaN
# 4    A4   B4   C4   D4  NaN
# 5    A5   B5   C5   D5  NaN
# 6    A6   B6   C6   D6  NaN
# 7    A7   B7   C7   D7  NaN
# 8    A8   B8   C8  NaN   D8
# 9    A9   B9   C9  NaN   D9
# 10  A10  B10  C10  NaN  D10
# 11  A11  B11  C11  NaN  D11

# %%
# Join
left_df = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2']
}, index=['K0', 'K1', 'K2']) 

right_df = pd.DataFrame({
    'C': ['C0', 'C2', 'C3'],
    'D': ['D0', 'D2', 'D3']
}, index=['K0', 'K2', 'K3'])

# %%
left_df
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right_df
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left_df.join(right_df,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
left_df.join(right_df,how='inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
# Merging on multiple keys
left = pd.DataFrame({
    'key1': ['K0', 'K0', 'K1', 'K2'],
    'key2': ['K0', 'K1', 'K0', 'K1'],
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
})
    
right = pd.DataFrame({
    'key1': ['K0', 'K1', 'K1', 'K2'],
    'key2': ['K0', 'K0', 'K0', 'K0'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
})

# %%
# other options are 'inner', 'left', 'right'
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
# Datetime format
date_df = pd.DataFrame({'date': ['3/10/2000', '3/11/2000', '3/12/2000'],
                   'value': [2, 3, 4]})

# %%
date_df
# Out:
#         date  value
# 0  3/10/2000      2
# 1  3/11/2000      3
# 2  3/12/2000      4

# %%
date_df = pd.DataFrame({'date': ['3/10/2000', '3/11/2000', '3/12/2000'],
                   'value': [2, 3, 4]})
date_df['date'] = pd.to_datetime(date_df['date'], dayfirst=True)

# %%
date_df
# Out:
#         date  value
# 0 2000-10-03      2
# 1 2000-11-03      3
# 2 2000-12-03      4

# %%
date1_df = pd.DataFrame({'date': ['2016-6-10 20:30:0', 
                            '2016-7-1 19:45:30', 
                            '2013-10-12 4:5:1'],
                   'value': [2, 3, 4]})
date1_df['date'] = pd.to_datetime(date1_df['date'], format="%Y-%d-%m %H:%M:%S")

# %%
date1_df
# Out:
#                  date  value
# 0 2016-10-06 20:30:00      2
# 1 2016-01-07 19:45:30      3
# 2 2013-12-10 04:05:01      4

# %%
df2 = pd.DataFrame({'date': ['3/10/2000', 'a/11/2000', '3/12/2000'],
                   'value': [2, 3, 4]})
df2
# Out:
#         date  value
# 0  3/10/2000      2
# 1  a/11/2000      3
# 2  3/12/2000      4

# %%
df2['date'] = pd.to_datetime(df2['date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 df2['date'] = pd.to_datetime(df2['date'])
#
# File ~\Documents\Anu_Documents\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\Documents\Anu_Documents\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
df2['date'] = pd.to_datetime(df2['date'],errors='ignore')
df2
# Out:
# C:\Users\Aruna Tangirala\AppData\Local\Temp\ipykernel_20296\2294145562.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df2['date'] = pd.to_datetime(df2['date'],errors='ignore')
#         date  value
# 0  3/10/2000      2
# 1  a/11/2000      3
# 2  3/12/2000      4

# %%
df2['date'] = pd.to_datetime(df2['date'],errors='coerce')
df2
# Out:
#         date  value
# 0 2000-03-10      2
# 1        NaT      3
# 2 2000-03-12      4

# %%
df3 = pd.DataFrame({'year': [2015, 2016],
                   'month': [2, 3],
                   'day': [4, 5]})
df3
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
df3['date']=pd.to_datetime(df3)
df3
# Out:
#    year  month  day       date
# 0  2015      2    4 2015-02-04
# 1  2016      3    5 2016-03-05

# %%
df4['Year'] =df3['date'].dt.year
df4
# Out:
# C:\Users\Aruna Tangirala\AppData\Local\Temp\ipykernel_20296\3743220889.py:1: SettingWithCopyWarning: modifications to a property of a datetimelike object are not supported and are discarded. Change values on the original.
#   df4['Year'] =df3['date'].dt.year
# 0                                               2015
# 1                                               2016
# Year    0    2015
# 1    2016
# Name: date, dtype: int32
# Name: date, dtype: object

# %%
df4
# Out:
# 0                                               2015
# 1                                               2016
# Year    0    2015
# 1    2016
# Name: date, dtype: int32
# Name: date, dtype: object

# %%
df3
# Out:
#    year  month  day       date
# 0  2015      2    4 2015-02-04
# 1  2016      3    5 2016-03-05

# %%
df20=pd.DataFrame()
df20['Year']=df3['date'].dt.year
df20['Month']=df3['date'].dt.month
df20['Day']=df3['date'].dt.day
df20
# Out:
#    Year  Month  Day
# 0  2015      2    4
# 1  2016      3    5

# %%
df21 = pd.DataFrame({'name': ['Tom', 'Andy', 'Lucas'],
                 'DoB': ['08-05-1997', '04-28-1996', '12-16-1995']})
df21
# Out:
#     name         DoB
# 0    Tom  08-05-1997
# 1   Andy  04-28-1996
# 2  Lucas  12-16-1995

# %%
df21['DoB'] = pd.to_datetime(df21['DoB'])

df21['Year']=df21['DoB'].dt.year
df21['Month']=df21['DoB'].dt.month
df21['Day']=df21['DoB'].dt.day

df21
# Out:
#     name        DoB  Year  Month  Day
# 0    Tom 1997-08-05  1997      8    5
# 1   Andy 1996-04-28  1996      4   28
# 2  Lucas 1995-12-16  1995     12   16

# %%
df21['Week_of_Year']= df21['DoB'].dt.isocalendar().week
df21['day_of_week']= df21['DoB'].dt.dayofweek
df21['is_leap_year']= df21['DoB'].dt.is_leap_year

df21
# Out:
#     name        DoB  Year  Month  Day  day_of_week  is_leap_year  Week_of_Year
# 0    Tom 1997-08-05  1997      8    5            1         False            32
# 1   Andy 1996-04-28  1996      4   28            6          True            17
# 2  Lucas 1995-12-16  1995     12   16            5         False            50

# %%
dw_mapping={
    0: 'Monday', 
    1: 'Tuesday', 
    2: 'Wednesday', 
    3: 'Thursday', 
    4: 'Friday',
    5: 'Saturday', 
    6: 'Sunday'
} 

df21['day_of_week_name']=df21['DoB'].dt.weekday.map(dw_mapping)

# %%
df21
# Out:
#     name        DoB  Year  Month  Day  day_of_week  is_leap_year  \
# 0    Tom 1997-08-05  1997      8    5            1         False
# 1   Andy 1996-04-28  1996      4   28            6          True
# 2  Lucas 1995-12-16  1995     12   16            5         False
#
#    Week_of_Year day_of_week_name
# 0            32          Tuesday
# 1            17           Sunday
# 2            50         Saturday

# %%
# Get the age from the date of birth
Today = pd.to_datetime('today')
df21['age']=Today.year - df21['Year']

Today
# Out:
# Timestamp('2025-01-31 19:56:36.026678')

# %%
df21
# Out:
#     name        DoB  Year  Month  Day  day_of_week  is_leap_year  \
# 0    Tom 1997-08-05  1997      8    5            1         False
# 1   Andy 1996-04-28  1996      4   28            6          True
# 2  Lucas 1995-12-16  1995     12   16            5         False
#
#    Week_of_Year day_of_week_name  age
# 0            32          Tuesday   28
# 1            17           Sunday   29
# 2            50         Saturday   30
